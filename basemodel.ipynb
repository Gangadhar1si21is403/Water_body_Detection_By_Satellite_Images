# %%
use

# %%
from gugoogle.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     131     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
cd dpm_tensorflow
# Out:
# [Errno 2] No such file or directory: 'dpm_tensorflow'
# /content

# %%
cd /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow
# Out:
# /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow

# %%
# !pip install imagehash
# Out:
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.11.4)
# Installing collected packages: imagehash
# Successfully installed imagehash-4.3.1

# %%
from numpy import asarray
import numpy as np

import os
import cv2
import glob
import imagehash
from PIL import Image

import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout
from keras import optimizers
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from pickle import dump

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# b) Load dataset

images = sorted(glob.glob("/content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/*.jpg"))
masks = sorted(glob.glob("/content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Masks/*.jpg"))

print(len(images), len(masks))
# Out:
# 1248 1248

# %%
# a) Image visualization
# plot first few random images in Images and Masks folder
f, axr = plt.subplots(10,2, figsize=(12,36))
for i in range(10):
    idx = np.random.randint(0, len(images))
    original = cv2.imread(images[idx])
    mask = cv2.imread(masks[idx])
    axr[i,0].imshow(original)
    axr[i,1].imshow(mask)
    i +=1
    axr[0, 0].set_title("IMAGE")
    axr[0, 1].set_title("MASK")

# %%
# Calculate statistics of the image dimensions
dimen_img_list = []

for img in images:
    img = cv2.imread(img, cv2.COLOR_BGR2RGB)
    dimen_img = img.shape[:2]
    dimen_img_list.append(dimen_img)

# Convert the list to numpy array
dimen_img_array = np.array(dimen_img_list)

# %%
# Calculate statistics of the image dimensions
print("Statistics of image dimensions:")
print("Minimum width:", np.min(dimen_img_array[:, 1]))
print("Maximum width:", np.max(dimen_img_array[:, 1]))
print("Mean width:", np.mean(dimen_img_array[:, 1]))
print("Median width:", np.median(dimen_img_array[:, 1]))
print("Standard deviation of width:", np.std(dimen_img_array[:, 1]))
print("Minimum height:", np.min(dimen_img_array[:, 0]))
print("Maximum height:", np.max(dimen_img_array[:, 0]))
print("Mean height:", np.mean(dimen_img_array[:, 0]))
print("Median height:", np.median(dimen_img_array[:, 0]))
print("Standard deviation of height:", np.std(dimen_img_array[:, 0]))
# Out:
# Statistics of image dimensions:
# Minimum width: 12
# Maximum width: 5640
# Mean width: 462.3838141025641
# Median width: 270.0
# Standard deviation of width: 575.1263024279336
# Minimum height: 7
# Maximum height: 7093
# Mean height: 647.7227564102565
# Median height: 392.0
# Standard deviation of height: 790.1273388495872

# %%
# Plot the histogram
plt.hist(dimen_img_array[:, 1], bins=50, alpha=0.5, color='blue', label='width')
plt.hist(dimen_img_array[:, 0], bins=50, alpha=0.5, color='red', label='height')
plt.xlabel('Dimensions')
plt.ylabel('Frequency')
plt.title('Histogram of Image Dimensions')
plt.legend()
plt.show()

# %%
# Plot the histogram
plt.hist(dimen_img_array[:, 1], bins=50, alpha=0.5, color='blue', label='width')
plt.hist(dimen_img_array[:, 0], bins=50, alpha=0.5, color='red', label='height')
plt.xlabel('Dimensions')
plt.ylabel('Frequency')
plt.title('Histogram of Image Dimensions')
plt.legend()
plt.show()

# %%
# a) Data Cleaning

#Detect and remove duplicate images and masks
hashes = {}
to_remove = []

for file in images:
    if file.endswith('.jpg'):
        with open(file, 'rb') as f:
            img = Image.open(f)
            # Compute the hash value for the image
            h = imagehash.phash(img)
            # Check if the hash value already exists in the dictionary
            if h in hashes:
                print(f'Duplicate image found: {file} and {hashes[h]}')
                to_remove.append(file)
                mask_file = os.path.join("/content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Masks", os.path.basename(file))
                to_remove.append(mask_file)
            else:
                hashes[h] = file
# Out:
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1244.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1333.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1552.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1619.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1659.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_2312.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_608.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_636.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_778.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg
# Duplicate image found: /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_810.jpg and /content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Images/water_body_1023.jpg

# %%
# Create a new list of filenames that excludes the duplicates
new_images = [file for file in images if file not in to_remove]
new_masks = [os.path.join("/content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow/Water Bodies Dataset - Copy/Masks", os.path.basename(file)) for file in new_images]
print(len(new_images), len(new_masks))
# Out:
# 1238 1238

# %%
# Load, filter blank and abnormal size images and masks, and resize them to the median values or larger

min_size = 32
df_images = []
df_masks = []

height = width = 300

for image, mask in zip(new_images, new_masks):
    #cv2.imread reads image in BGR, we need to convert it back to the standard mode RGB
    n = cv2.imread(image, cv2.COLOR_BGR2RGB)
    m = cv2.imread(mask, cv2.IMREAD_GRAYSCALE)

    # Check if the image has size > min_size and is entirely black or white
    if min(n.shape[:2]) > min_size and ((m != 0).any() and (m != 255).any()):
        n = cv2.resize(n, (height, width)) # resize to median values or larger
        df_images.append(n)
        m = cv2.resize(m, (height, width)) # resize to median values or larger
        df_masks.append(m)

# Convert image into array of pixels
df_images = asarray(df_images)

# Convert mask into array of pixels
df_masks = asarray(df_masks)

print(len(df_images), len(df_masks))
# Out:
# 1163 1163

# %%
# b) Split data into train and test sets

X = df_images
y = df_masks

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=1)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.015, random_state=1)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape)
# Out:
# (872, 300, 300, 3) (872, 300, 300) (286, 300, 300, 3) (286, 300, 300) (5, 300, 300, 3) (5, 300, 300)

# %%
# Flatten images and convert data from numpy array to float type
X_train = X_train.reshape(X_train.shape[0], height, width, 3).astype('float32')
X_test = X_test.reshape(X_test.shape[0], height, width, 3).astype('float32')
X_val = X_val.reshape(X_val.shape[0], height, width, 3).astype('float32')
y_train = y_train.reshape(y_train.shape[0], height, width).astype('float32')
y_test = y_test.reshape(y_test.shape[0], height, width).astype('float32')
y_val = y_val.reshape(y_val.shape[0], height, width).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
X_val = X_val / 255
y_train = y_train / 255
y_test = y_test / 255
y_val = y_val / 255

# %%
input_shape = (height, width, 3)

def base_model(input_shape):
    inputs = layers.Input(shape=input_shape)

    # Encoding layers
    conv1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    # Decoding layers
    up3 = layers.UpSampling2D(size=(2, 2))(pool2)
    conv3 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(up3)
    conv4 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(conv3)
    up5 = layers.UpSampling2D(size=(2, 2))(conv4)
    outputs = layers.Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(up5)

    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model
model = base_model(input_shape)

# Reshape target data to match output shape of the model
y_train = y_train.reshape(-1, height, width, 1)
y_test = y_test.reshape(-1, height, width, 1)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (872, 300, 300, 3) (286, 300, 300, 3)

# %%
# Evaluate accuracy on the test set
accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)

# Make predictions on the test set
predictions = model.predict(X_test)

# You can use predictions as needed for further analysis
# For example, if you want the predicted classes (assuming a classification problem with softmax output):
predicted_classes = np.argmax(predictions, axis=1)

# If you want the raw prediction probabilities:
raw_probabilities = predictions

# If you want to compare the predictions with the actual labels
# (useful for classification problems):
compare_results = np.equal(predicted_classes, np.argmax(y_test, axis=1))
# Out:
# 9/9 [==============================] - 7s 297ms/step - loss: 0.6938 - accuracy: 0.2482
# Test Accuracy: [0.6938145756721497, 0.24818609654903412]
# 9/9 [==============================] - 1s 60ms/step

# %%
# Define a callback for early stopping if the validation loss does not improve for 10 consecutive
# epochs (patience=10).
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Fit the model to train and test sets
history = model.fit(X_train, y_train, batch_size=64, epochs=30, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 14/14 [==============================] - 29s 1s/step - loss: 0.6008 - accuracy: 0.5673 - val_loss: 0.5564 - val_accuracy: 0.5880
# Epoch 2/30
# 14/14 [==============================] - 5s 366ms/step - loss: 0.5304 - accuracy: 0.6203 - val_loss: 0.4944 - val_accuracy: 0.7054
# Epoch 3/30
# 14/14 [==============================] - 5s 363ms/step - loss: 0.4894 - accuracy: 0.6891 - val_loss: 0.4597 - val_accuracy: 0.7093
# Epoch 4/30
# 14/14 [==============================] - 5s 379ms/step - loss: 0.4703 - accuracy: 0.6893 - val_loss: 0.4452 - val_accuracy: 0.7067
# Epoch 5/30
# 14/14 [==============================] - 5s 363ms/step - loss: 0.4642 - accuracy: 0.6873 - val_loss: 0.4517 - val_accuracy: 0.7037
# Epoch 6/30
# 14/14 [==============================] - 5s 374ms/step - loss: 0.4546 - accuracy: 0.6919 - val_loss: 0.4641 - val_accuracy: 0.7046
# Epoch 7/30
# 14/14 [==============================] - 5s 378ms/step - loss: 0.4644 - accuracy: 0.6852 - val_loss: 0.4331 - val_accuracy: 0.7080
# Epoch 8/30
# 14/14 [==============================] - 5s 371ms/step - loss: 0.4444 - accuracy: 0.6937 - val_loss: 0.4231 - val_accuracy: 0.7125
# Epoch 9/30
# 14/14 [==============================] - 6s 441ms/step - loss: 0.4259 - accuracy: 0.7025 - val_loss: 0.4258 - val_accuracy: 0.7100
# Epoch 10/30
# 14/14 [==============================] - 5s 375ms/step - loss: 0.4302 - accuracy: 0.6936 - val_loss: 0.4216 - val_accuracy: 0.7157
# Epoch 11/30
# 14/14 [==============================] - 6s 431ms/step - loss: 0.4252 - accuracy: 0.7045 - val_loss: 0.4072 - val_accuracy: 0.7142
# Epoch 12/30
# 14/14 [==============================] - 5s 381ms/step - loss: 0.4135 - accuracy: 0.7127 - val_loss: 0.3941 - val_accuracy: 0.7198
# Epoch 13/30
# 14/14 [==============================] - 5s 382ms/step - loss: 0.4125 - accuracy: 0.7096 - val_loss: 0.3928 - val_accuracy: 0.7161
# Epoch 14/30
# 14/14 [==============================] - 6s 399ms/step - loss: 0.3958 - accuracy: 0.7200 - val_loss: 0.3798 - val_accuracy: 0.7216
# Epoch 15/30
# 14/14 [==============================] - 5s 393ms/step - loss: 0.3921 - accuracy: 0.7219 - val_loss: 0.4104 - val_accuracy: 0.7079
# Epoch 16/30
# 14/14 [==============================] - 6s 411ms/step - loss: 0.3978 - accuracy: 0.7183 - val_loss: 0.3819 - val_accuracy: 0.7258
# Epoch 17/30
# 14/14 [==============================] - 6s 396ms/step - loss: 0.3833 - accuracy: 0.7226 - val_loss: 0.3765 - val_accuracy: 0.7334
# Epoch 18/30
# 14/14 [==============================] - 6s 452ms/step - loss: 0.3754 - accuracy: 0.7254 - val_loss: 0.3933 - val_accuracy: 0.7191
# Epoch 19/30
# 14/14 [==============================] - 6s 402ms/step - loss: 0.3773 - accuracy: 0.7247 - val_loss: 0.3962 - val_accuracy: 0.7217
# Epoch 20/30
# 14/14 [==============================] - 5s 394ms/step - loss: 0.3800 - accuracy: 0.7277 - val_loss: 0.3772 - val_accuracy: 0.7213
# Epoch 21/30
# 14/14 [==============================] - 6s 399ms/step - loss: 0.3698 - accuracy: 0.7273 - val_loss: 0.3649 - val_accuracy: 0.7318
# Epoch 22/30
# 14/14 [==============================] - 5s 386ms/step - loss: 0.3629 - accuracy: 0.7296 - val_loss: 0.3838 - val_accuracy: 0.7209
# Epoch 23/30
# 14/14 [==============================] - 6s 401ms/step - loss: 0.3699 - accuracy: 0.7301 - val_loss: 0.3777 - val_accuracy: 0.7344
# Epoch 24/30
# 14/14 [==============================] - 5s 382ms/step - loss: 0.3706 - accuracy: 0.7315 - val_loss: 0.3547 - val_accuracy: 0.7386
# Epoch 25/30
# 14/14 [==============================] - 5s 387ms/step - loss: 0.3621 - accuracy: 0.7314 - val_loss: 0.3518 - val_accuracy: 0.7392
# Epoch 26/30
# 14/14 [==============================] - 5s 391ms/step - loss: 0.3758 - accuracy: 0.7273 - val_loss: 0.3760 - val_accuracy: 0.7395
# Epoch 27/30
# 14/14 [==============================] - 5s 385ms/step - loss: 0.3736 - accuracy: 0.7283 - val_loss: 0.3783 - val_accuracy: 0.7322
# Epoch 28/30
# 14/14 [==============================] - 6s 445ms/step - loss: 0.3742 - accuracy: 0.7275 - val_loss: 0.3656 - val_accuracy: 0.7446
# Epoch 29/30
# 14/14 [==============================] - 6s 439ms/step - loss: 0.3626 - accuracy: 0.7312 - val_loss: 0.3542 - val_accuracy: 0.7425
# Epoch 30/30
# 14/14 [==============================] - 6s 409ms/step - loss: 0.3609 - accuracy: 0.7338 - val_loss: 0.3685 - val_accuracy: 0.7395

# %%
# Plot diagnostic learning curves
plt.title('Model Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc ="upper right")

# %%
# Evaluate accuracy on the test set
accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)

# Make predictions on the test set
predictions = model.predict(X_test)

# You can use predictions as needed for further analysis
# For example, if you want the predicted classes (assuming a classification problem with softmax output):
predicted_classes = np.argmax(predictions, axis=1)

# If you want the raw prediction probabilities:
raw_probabilities = predictions

# If you want to compare the predictions with the actual labels
# (useful for classification problems):
compare_results = np.equal(predicted_classes, np.argmax(y_test, axis=1))
# Out:
# 9/9 [==============================] - 1s 69ms/step - loss: 0.3685 - accuracy: 0.7395
# Test Accuracy: [0.3685058653354645, 0.7395250797271729]
# 9/9 [==============================] - 1s 56ms/step

# %%
gen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

# %%
train_gen = gen.flow(X_train, y_train, batch_size=64)
test_gen = gen.flow(X_test, y_test, batch_size=64)

# %%
model2 = base_model(input_shape)

# %%
history2 = model2.fit(train_gen, epochs=30, batch_size=64, validation_data=test_gen, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 14/14 [==============================] - 40s 3s/step - loss: 0.5225 - accuracy: 0.6599 - val_loss: 0.5133 - val_accuracy: 0.6695
# Epoch 2/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5236 - accuracy: 0.6592 - val_loss: 0.5143 - val_accuracy: 0.6690
# Epoch 3/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5186 - accuracy: 0.6668 - val_loss: 0.5095 - val_accuracy: 0.6715
# Epoch 4/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5174 - accuracy: 0.6644 - val_loss: 0.5069 - val_accuracy: 0.6757
# Epoch 5/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5160 - accuracy: 0.6659 - val_loss: 0.5141 - val_accuracy: 0.6664
# Epoch 6/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5315 - accuracy: 0.6523 - val_loss: 0.5349 - val_accuracy: 0.6463
# Epoch 7/30
# 14/14 [==============================] - 25s 2s/step - loss: 0.5222 - accuracy: 0.6602 - val_loss: 0.5132 - val_accuracy: 0.6696
# Epoch 8/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5319 - accuracy: 0.6574 - val_loss: 0.5216 - val_accuracy: 0.6654
# Epoch 9/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5194 - accuracy: 0.6637 - val_loss: 0.5137 - val_accuracy: 0.6709
# Epoch 10/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5191 - accuracy: 0.6642 - val_loss: 0.5121 - val_accuracy: 0.6710
# Epoch 11/30
# 14/14 [==============================] - 25s 2s/step - loss: 0.5175 - accuracy: 0.6669 - val_loss: 0.5144 - val_accuracy: 0.6662
# Epoch 12/30
# 14/14 [==============================] - 31s 2s/step - loss: 0.5160 - accuracy: 0.6644 - val_loss: 0.5099 - val_accuracy: 0.6712
# Epoch 13/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5131 - accuracy: 0.6680 - val_loss: 0.5122 - val_accuracy: 0.6722
# Epoch 14/30
# 14/14 [==============================] - 26s 2s/step - loss: 0.5208 - accuracy: 0.6609 - val_loss: 0.5358 - val_accuracy: 0.6619

# %%
plt.title('Model Loss')
plt.plot(history2.history['loss'], color='blue', label='train')
plt.plot(history2.history['val_loss'], color='orange', label='test')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Test"], loc ="upper right")

# %%
# Evaluate accuracy on the test set
accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)

# Make predictions on the test set
predictions = model.predict(X_test)

# You can use predictions as needed for further analysis
# For example, if you want the predicted classes (assuming a classification problem with softmax output):
predicted_classes = np.argmax(predictions, axis=1)

# If you want the raw prediction probabilities:
raw_probabilities = predictions

# If you want to compare the predictions with the actual labels
# (useful for classification problems):
compare_results = np.equal(predicted_classes, np.argmax(y_test, axis=1))
# Out:
# 9/9 [==============================] - 1s 75ms/step - loss: 0.3685 - accuracy: 0.7395
# Test Accuracy: [0.3685058653354645, 0.7395250797271729]
# 9/9 [==============================] - 0s 52ms/step

# %%
Pred = model.predict(X_val)

# Plot original and predicted images
fig, ax = plt.subplots(5, 3, figsize=(12,40))
for i in range(1):
    orig = X_val[i]
    msk = y_val[i]
    pred = Pred[i]
    ax[i,0].imshow(orig)
    ax[i,1].imshow(msk, cmap='gray')
    ax[i,2].imshow(pred, cmap='gray')
    i +=1
    ax[0, 0].set_title("IMAGE")
    ax[0, 1].set_title("MASK")
    ax[0, 2].set_title("PREDICTION")

# %%
# b) Save the model for later use

# save the model to disk
filename = 'finalized_model.sav'
dump(model, open(filename, 'wb'))
model.save('/content/drive/MyDrive/Major_project_2023-24/dpm_tensorflow')
